# %%
splash:go('https://kiliim.com/shop/')
# Out:
# true

# %%
currency = splash:evaljs('document.querySelectorAll("span.woocommerce-Price-currencySymbol")[0].innerHTML')

# %%
currency
# Out:
# " EGP"

# %%
ok = 1

# %%
if currency ~= "EGP" then
    ok = 0
end

# %%
ok
# Out:
# 0

# %% [markdown]
# ## Testing Lua Script

# %%
splash:go('https://kiliim.com/product/blue-nile-cushion/')
# Out:
# true

# %%
button = splash:select('button.single_add_to_cart_button')

# %%
button:mouse_click()
# Out:
# true

# %%
splash:wait(1.5)
# Out:
# true

# %%
splash:go('https://kiliim.com/checkout/')
# Out:
# true

# %%
select_input = splash:select('#s2id_billing_country')

# %%
splash:png()

# %%
select_input:mouse_click()
# Out:
# true

# %%
splash:png()

# %%
country = splash:select('input[id=s2id_autogen1_search]')

# %% [markdown]
# # Now select country to trigger PriceBasedonCountry

# %%
country:send_text("France")
# Out:
# true, nil

# %%
country:send_keys("<Return>")
# Out:
# true, nil

# %%
splash:png()

# %% [markdown]
# ##  Test new currency

# %%
splash:go('https://kiliim.com/product/blue-nile-cushion/')
# Out:
# true

# %%
splash:png()

# %%
splash:html()
# Out:
# "<!DOCTYPE html><html class=\"\" lang=\"en-US\" prefix=\"og: http://ogp.me/ns#\"><head>\n\t\t<meta name=\"description\" content=\"Kiliim is an Egyptian social enterprise and a lifestyle brand that aims to revive and sustain the local craft of handmade kilim making in Egypt by introducing modern designs to a time-honored technique. We manufacture our kilims in Fowwa, a small village situated along the lush Nile Delta. Our craftsmen come from a long line of kilim artisans who consider the craft as part of their heritage. We use the finest quality wool yarn and dyes that are guaranteed to last a lifetime.\">\n\t\t<meta charset=\"UTF-8\">\n\t\t<meta name=\"viewport\" content=\"width=device-width, initial-scale=1.0\">\n\t\t<script id=\"facebook-jssdk\" src=\"//connect.facebook.net/en_US/sdk.js\"></script><script async=\"\" src=\"https://www.google-analytics.com/analytics.js\"></script><script>\n\t\t\t(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){\n\t\t\t(i[r]
# ...
